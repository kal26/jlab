# %% [markdown]
# ## In Class Excersise 2: Representing Uncertainty
#
# The goals of this exercise are:
# * to get you off the ground with a software analysis platform in learning how to load, manipulate, and plot data;
# * to have you calculate basic statistical properties of your data; and
# * to have you face the practicalities of making a “good” plot for presentation purposes.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# __Load the data into your software,__ creating variables from the data file for the dimensions
# x, y, and z, and the volume V .

# %%
# downloading and getting data into a table 
cube = pd.read_table('/home/kal/jLab/cubeData.csv', delimiter=',', header=None)
cube.columns = 'YY.Mmm.B0X.nn num x x_uncert y y_uncert z z_uncert volume v_uncert'.split()
cube.head()
# Out:
#    YY.Mmm.B0X.nn  num    x  x_uncert     y  y_uncert     z  z_uncert  volume  \
# 0  14.Sep.B01.01    1  9.0       0.2  10.4       0.2  36.8       0.3  3400.0
# 1  14.Sep.B01.02    2  9.1       0.6  10.5       1.0  36.8       0.8  3500.0
# 2  14.Sep.B01.03    3  8.9       0.1  10.1       0.3  36.5       0.3  3281.0
# 3  14.Sep.B01.04    4  9.0       0.5  10.4       0.5  36.9       0.5  3400.0
# 4  14.Sep.B01.05    5  8.9       0.1  10.4       0.1  37.0       0.1  3400.0
#
#    v_uncert
# 0    200.00
# 1    400.00
# 2      0.44
# 3      0.90
# 4     51.00

# %% [markdown]
# __Examine the table of data by eye.__ Are all the points reasonable? Perform any
# simple calculations necessary to help this judgment. Give all points equal scrutiny so
# as to avoid introducing a bias. Decide to either use the volume data as reported or to
# recompute it yourself.

# %%
for key in 'x x_uncert y y_uncert z z_uncert volume v_uncert'.split():
        plt.hist(cube[key])
        plt.title('Number of samples vs {} measured on a cuboid'.format(key))
        plt.xlabel('{} value (cm)'.format(key))
        plt.ylabel('Number of Counts')
        plt.show()

# %% [markdown]
# I'm going to recompute volume myself - there appear to be some errors in volume calculation. No outliers are too crazy, but there is definetly variation.

# %%
cube['calculated_v'] = cube['x'] * cube['y'] * cube['z']
plt.scatter(cube['calculated_v'], cube['volume'])
plt.title('Reported vs Calculated Cuboid Volume')
plt.ylabel('Reported Volume (mm^3)')
plt.xlabel('Recalculated Volume (mm^3)')
plt.show()

# %% [markdown]
# __Examine the data statistically.__ Compute the following quantities for each of x, y,
# z, and V :
# * the mean of the data,
# * the standard deviation of the data, and
# * your best estimate for the mean of the parent distribution from which this data is sampled and your uncertainty in that estimated mean.
#
# Again, ask yourself if the results of your calculations are reasonable.

# %%
# calculated values
d = {'label':['x', 'y', 'z', 'volume', 'calculated_v']}
overall = pd.DataFrame(data=d)
for index, row in overall.iterrows():
    overall.at[index, 'mean'] = np.mean(cube[row['label']])
    overall.at[index, 'stdev'] = np.std(cube[row['label']])
overall.head()
# Out:
#           label         mean       stdev
# 0             x     9.019166    0.154085
# 1             y    10.316020    0.340972
# 2             z    36.670373    0.727959
# 3        volume  3399.649818  267.484927
# 4  calculated_v  3412.508693  158.108790

# %% [markdown]
# Some of the points in the distributsions are outliers, likely due to confusing the axis or miscounting ticks. Disregarding these give me my best guess for the mean of the distribution.
#
# * X: $9.0 \pm .2$
# * Y: $10.3 \pm .3$
# * Z: $36.8 \pm .3$
# * volume: $3400 \pm 200$

# %%
for key in 'x y calculated_v'.split():
    plt.hist(cube[key])
    plt.title('Number of samples vs {} measured on a cuboid'.format(key))
    plt.xlabel('{} value (cm)'.format(key))
    plt.ylabel('Number of Counts')
    plt.show()
    
plt.hist(cube[cube['z'] >34]['z'])
plt.title('Number of samples vs {} measured on a cuboid'.format(key))
plt.xlabel('z value (cm)')
plt.ylabel('Number of Counts')
plt.show()
print(np.mean(cube[cube['z'] >34]['z']))
print(np.std(cube[cube['z'] >34]['z']))
# Out:
# 36.75917592592593
# 0.32425189764154433

# %% [markdown]
# __Examine the volume data by plotting it as a histogram__

# %%
x_vals = np.linspace(2500, 4500, 200)

fig, ax = plt.subplots()

bins= np.linspace(2500, 4500, 50)

ax.hist(cube['calculated_v'], bins=bins)
ax.set_title('Counts vs Volume for Measurments of an Cuboid')
ax.set_ylabel('Number of Samples (count)')
ax.set_xlabel('Volume - Recalculated (cm^3)')

def gaussian(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))

mu=3412.508693
sigma=158.108790
ax.plot(x_vals, 40*gaussian(x_vals, mu, sigma))

textstr = '$\mu={}$\n$\sigma={}$'.format(3410, 160)

# these are matplotlib.patch.Patch properties
props = dict(boxstyle='round', alpha=0.5)

# place a text box in upper left in axes coords
ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)


plt.show()

# %%
# or, a prettier version
import matplotlib.style
import matplotlib as mpl
mpl.style.use('classic')


x_vals = np.linspace(2500, 4500, 200)

fig, ax = plt.subplots()

bins= np.linspace(2500, 4500, 50)

ax.hist(cube['calculated_v'], bins=bins)
ax.set_title('Number Samples vs Volume for Measurments of an Cuboid')
ax.set_ylabel('Number of Samples (count)')
ax.set_xlabel('Volume - Recalculated (cm^3)')

ax.plot(x_vals, 40*gaussian(x_vals, mu, sigma))

# these are matplotlib.patch.Patch properties
props = dict(boxstyle='round', alpha=0.5)

# place a text box in upper left in axes coords
ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)


plt.show()

# %% [markdown]
# Now, create a paper quality graphic

# %%
# or, a prettier version
mpl.rcParams['mathtext.fontset'] = 'stix'
mpl.rcParams['font.family'] = 'STIXGeneral'

#set up plot
x_vals = np.linspace(2500, 4500, 200)
fig, ax = plt.subplots()

#histogram
bins= np.linspace(2500, 4500, 50)
ax.hist(cube['calculated_v'], bins=bins, alpha=0.5)

#make text
#ax.set_title('Volume Distribution for \nMeasurments of a Cuboid')
#ax.title.set_fontsize(35)
ax.set_ylabel('Number of Samples (count)')
ax.yaxis.label.set_fontsize(25)
ax.set_xlabel('Volume (cm^3)')
ax.xaxis.label.set_fontsize(25)
y = ax.get_yticklabels()
for i in y:
    i.set_fontsize(20)
    
x = ax.get_xticklabels()
for i in x:
    i.set_fontsize(20)

#plot gaussian
ax.plot(x_vals, 40*gaussian(x_vals, mu, sigma), c='black', linewidth='4')

# these are matplotlib.patch.Patch properties
props = dict(boxstyle='round', fc="b", alpha=0.5)

# place a text box in upper left in axes coords
ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=25,
        verticalalignment='top', bbox=props)


plt.show()
